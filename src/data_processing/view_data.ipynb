# %%
import pandas as pd
import json
import os
import re

# %%
DATA_DIR = os.path.join(
	os.getcwd(),
	"data/data/downloaded_e2e_dataset"
)

for filename in os.listdir(DATA_DIR):
	filepath = os.path.join(DATA_DIR, filename)
	if not filename.endswith(".json"):
		continue
	with open(filepath, "r") as f:
		json_file = json.load(f)
	if json_file.get("url") == "https://github.com/tuetschek/e2e-cleaning/raw/master/cleaned-data/train-fixed.no-ol.csv":
		data_filepath = filepath.replace(".json", "")

# %%
data_df = pd.read_csv(data_filepath)
data_df.head()
# Out:
#                                                   mr  \
# 0  name[The Eagle], eatType[coffee shop], food[Ja...
# 1  name[The Mill], eatType[coffee shop], food[Fre...
# 2  name[Loch Fyne], food[French], area[riverside]...
# 3  name[The Rice Boat], eatType[restaurant], food...
# 4  name[The Wrestlers], eatType[coffee shop], foo...
#
#                                                  ref  fixed  \
# 0  The Eagle is a low rated coffee shop near Burg...      0
# 1  Located near The Sorrento is a French Theme ea...      1
# 2  For luxurious French food, the Loch Fyne is lo...      1
# 3  The Rice Boat is an adult French restaurant wi...      1
# 4  The Wrestlers coffee shop serves Japanese food...      0
#
#                                              orig_mr
# 0  name[The Eagle], eatType[coffee shop], food[Ja...
# 1  name[The Mill], eatType[coffee shop], food[Fre...
# 2  name[Loch Fyne], food[French], customer rating...
# 3  name[The Rice Boat], food[French], customer ra...
# 4  name[The Wrestlers], eatType[coffee shop], foo...

# %%
for i, row in data_df.iterrows():
	if row["mr"] != row["orig_mr"]:
		print(row["mr"])
		print(row["orig_mr"])
		print(row["ref"])
		break
# Out:
# name[The Mill], eatType[coffee shop], food[French], area[riverside], near[The Sorrento]
# name[The Mill], eatType[coffee shop], food[French], priceRange[£20-25], area[riverside], near[The Sorrento]
# Located near The Sorrento is a French Theme eatery and coffee shop called The Mill, with a price range at £20-£25 it is in the riverside area.

# %%
data_df.drop(["mr"], inplace=True, axis=1)
data_df.head()
# Out:
#                                                  ref  fixed  \
# 0  The Eagle is a low rated coffee shop near Burg...      0
# 1  Located near The Sorrento is a French Theme ea...      1
# 2  For luxurious French food, the Loch Fyne is lo...      1
# 3  The Rice Boat is an adult French restaurant wi...      1
# 4  The Wrestlers coffee shop serves Japanese food...      0
#
#                                              orig_mr
# 0  name[The Eagle], eatType[coffee shop], food[Ja...
# 1  name[The Mill], eatType[coffee shop], food[Fre...
# 2  name[Loch Fyne], food[French], customer rating...
# 3  name[The Rice Boat], food[French], customer ra...
# 4  name[The Wrestlers], eatType[coffee shop], foo...

# %%
for i, row in data_df.head(10).iterrows():
	print("***")
	print(f"ref: {row["ref"]}")
	print(f"mr: {row["orig_mr"]}")
# Out:
# ***
# ref: The Eagle is a low rated coffee shop near Burger King and the riverside that is family friendly and is less than £20 for Japanese food.
# mr: name[The Eagle], eatType[coffee shop], food[Japanese], priceRange[less than £20], customer rating[low], area[riverside], familyFriendly[yes], near[Burger King]
# ***
# ref: Located near The Sorrento is a French Theme eatery and coffee shop called The Mill, with a price range at £20-£25 it is in the riverside area.
# mr: name[The Mill], eatType[coffee shop], food[French], priceRange[£20-25], area[riverside], near[The Sorrento]
# ***
# ref: For luxurious French food, the Loch Fyne is located by the river next to The Rice Boat.
# mr: name[Loch Fyne], food[French], customer rating[high], area[riverside], near[The Rice Boat]
# ***
# ref: The Rice Boat is an adult French restaurant with high customer rating  located in the Riverside area.
# mr: name[The Rice Boat], food[French], customer rating[average], area[riverside], familyFriendly[no]
# ***
# ref: The Wrestlers coffee shop serves Japanese food.  It is situated near Raja Indian Cuisine at the riverside.  Prices are less than £20.  It is not family-friendly.
# mr: name[The Wrestlers], eatType[coffee shop], food[Japanese], priceRange[less than £20], area[riverside], familyFriendly[no], near[Raja Indian Cuisine]
# ***
# ref: In the city centre lies Aromi, a French coffee shop for adults with a low customer rating.
# mr: name[Aromi], eatType[coffee shop], food[French], customer rating[low], area[city centre], familyFriendly[no]
# ***
# ref: The Phoenix is a fast food place located in the riverside area. They have moderate pricing and a customer rating of 3 out of 5.
# mr: name[The Phoenix], food[Fast food], priceRange[moderate], customer rating[3 out of 5], area[riverside]
# ***
# ref: A child friendly restaurant that has English food is Loch Fyne.
# mr: name[Loch Fyne], eatType[restaurant], food[English], familyFriendly[yes]
# ***
# ref: Taste of Cambridge is a restaurant with a customer rating of 3 out of 5 and and a price range of £20-£25
# mr: name[Taste of Cambridge], eatType[restaurant], priceRange[£20-25], customer rating[3 out of 5]
# ***
# ref: For a family-Friendly coffee shop Cocum can serve you Italian food at affordable prices.  The customer rating however is only average.
# mr: name[Cocum], eatType[coffee shop], food[Italian], priceRange[cheap], customer rating[average], familyFriendly[yes]

# %%
for r, row in data_df.iterrows():
	if "name[Taste of Cambridge]" in row["orig_mr"] and "eatType[restaurant]" in row["orig_mr"]:
		print(row["ref"])
# Out:
# Taste of Cambridge is a restaurant with a customer rating of 3 out of 5 and and a price range of £20-£25
# Taste of Cambridge is a restaurant ranging at less than 20 pounds. It has low ratings.
# Moderately priced, Taste of Cambridge is a restaurant with an unfortunately low customer rating.
# With prices ranging less than £20, Taste of Cambridge is a restaurant with average customer ratings.
# Taste of Cambridge is an average rated and cheap restaurant option.
# Taste of Cambridge is a low rated restaurant offering food for less than £20.
# For a cheap restaurant with a customer rating of 5 out of 5, try Taste of Cambridge.
# Taste of Cambridge is a restaurant that has a price range of £20-25, and a customer rating of 3 out of 5.
# Taste of Cambridge is a cheap restaurant. It has a customer rating of 5 out of 5.
# Taste of Cambridge is a low rated restaurant in the price range of less than £20.
# Taste of Cambridge, a restaurant in the £30 or more price range, has a 5 out of 5 customer rating.
# A restaurant with above average prices but low customer ratings is Taste of Cambridge.
# Taste of Cambridge is an expensive restaurant that was given a customer rating of 3 out of five star.
# Taste of Cambridge is a restaurant with customer rating 3 out of 5.  It is in the high price range.
# The Taste of Cambridge is a restaurant with high pricing and an average of 3 out of 5 client rating.
# Taste of Cambridge is a great restaurant rated 5 out of 5 star where the price range is above 30£.
# Taste of Cambridge gets a rating of 3 out of 5, it's a restaurant offering meals at £20-£25 a head
# Taste of Cambridge is a restaurant with an average customer rating. High price range.
# restaurant Taste of Cambridge is customer rated 3 out of 5 and has price range of £20-25.
# The Taste of Cambridge is a restaurant offering a price range of more than £30 and has a satisfactory customer rating.
# Taste of Cambridge is a restaurant offering cheap eats with an average rating.
# a 5 out of 5 customer rated cheap restaurant is Taste of Cambridge.
# Taste of Cambridge is a moderately priced restaurant with an average 1 out of 5 customer rating.
# Taste of Cambridge restaurant has above average prices and below average customer ratings.
# Taste of Cambridge restaurant received a 3 out of 5 rating from customers for it's average priced food.
# Taste of Cambridge is a restaurant serving cheap food with a 5 out of 5 customer rating.
# Customers of the Taste of Cambridge restaurant rated this restaurant a 3 out of 5.
# Taste of Cambridge has prices less than 20 and is a restaurant with a low rating.
# Taste of Cambridge is a cheap restaurant with a customer rating of 5 out of 5.
# Taste of Cambridge is a restaurant with a low customer rating and prices over £30.
# The Taste of Cambridge restaurant has an average customer rating with £20 less as the price range.
# Highly rated, the average price Taste of Cambridge provides restaurant prices between £20-£25.
# Taste of Cambridge is a restaurant with a price range of £30 plus and a high customer rating.
# Taste of Cambridge is a moderately priced restaurant with a 1 out of 5 customer rating.
# A restaurant named Taste of Cambridge has a high price range and an average customer rating.
# There is a restaurant,  Taste of Cambridge that is high rice range with customer rating of 1 out of 5.
# Taste of Cambridge is an expensive, highly rated restaurant.
# A restaurant with average ratings, in the price range of less than £20, is the Taste of Cambridge.
# A restaurant with high customer ratings is Taste of Cambridge with a price range of only £20.00 - £25.00.
# Taste of Cambridge is moderately priced restaurant, and has a 3 out if 5 star customer rating.
# Taste of Cambridge is a restaurant with an average customer rating, it is also cheap.
# There is a moderately priced, three out of five star rated restaurant named Taste of Cambridge.
# Even with its price range of £30 or more a person, the Taste of Cambridge restaurant has still averaged a 5 out of 5 customer rating.
# Taste of Cambridge is a restaurant that provide high quality food for cheap.
# Taste of Cambridge is a moderately priced restaurant with a rating of 1 out of 5.
# Taste of Cambridge is a restaurant with an average customer rating and a high price range.
# Taste of Cambridge is a new restaurant with prices ranging up to £20. Although not highly rated at the moment, it is becoming increasingly popular.
# Taste of Cambridge is a 3 out of 5 customer rated restaurant with a moderate price range.
# Taste of Cambridge is a restaurant with a high price range and an average customer rating.
# With a price range of £30 upwards, the Taste of Cambridge is a restaurant with a high customer rating.
# Taste of Cambridge is a high price range restaurant with the customer rating of 1 out of 5.
# The Taste of Cambridge is an expensive, but highly rated restaurant.
# the Taste of Cambridge is a restaurant that has a customer Rating of 5 out of 5 with a price range of more than £30 per person
# A restaurant with average reviews for less than £20 is Taste of Cambridge.
# Taste of Cambridge is a low-priced restaurant. The customer ratings are low.
# Due to high prices, the Taste of Cambridge restaurant has a poor 1 out of 5 customer rating.
# A restaurant with a customer rating of 5 out of 5 is Taste of Cambridge. Their price range is more than 30.
# The price range of the restaurant Taste of Cambridge is high, and it has a customer rating of 1 out of 5 stars.
# The Taste of Cambridge is a eat type restaurant with a price range of less than 20 and an average customer rating.
# restaurant named Taste of Cambridge, Price range of £20-25, and customer rating of 3 out of 5.
# Taste of Cambridge has a average price range of £20-25. it is a highly rated restaurant.
# Moderately priced Taste of Cambridge is a restaurant rated 1 out of 5 by customers.
# Taste of Cambridge  is a restaurant  price range more than £30  high customer rating
# Taste of Cambridge has a moderate price range with a 1 out of 5 customer rating restaurant
# Taste of Cambridge is a cheap restaurant.  Customer rating is 5 out of 5.
# The Taste of Cambridge is a high priced restaurant with a 3 out of 5 rating.
# Taste of Cambridge is an expensive restaurant with a low rating.
# A low price restaurant is Taste of Cambridge, though it's rated low with customers.
# There is a  average rated restaurant named Taste of Cambridge with cheap prices.
# An expensive restaurant called Taste of Cambridge has a customer rating of 3 out of 5.
# With a high price range and an average customer rating, Taste of Cambridge is  new restaurant.
# Taste of Cambridge is a 1 star restaurant with moderate prices.
# Taste of Cambridge  is a restaurant  price range more than £30  high customer rating
# Taste of Cambridge is a cheap restaurant with average customer rating.
# Taste of Cambridge is a restaurant based in the city centre serving scummy food.  The average price of a  meal is above average at   £30 per head
# A restaurant highly rated by customers, and averagely priced is Taste of Cambridge.
# Taste of Cambridge is a moderate priced restaurant with a 1 out of 5 customer rating.
# Taste of Cambridge is a moderately priced, three out of five star rated restaurant.
# For a restaurant in the cheap price range with a customer rating of 5 out of 5, try Taste of Cambridge
# With an average customer rating, Taste of Cambridge is a high priced restaurant.
# A restaurant with a high price range is called the Taste of Cambridge. It gets 3 out of 5 for ratings.
# Taste of Cambridge restaurant received 5 out of 5 star score. The place offers dishes for more than 30L.
# Taste of Cambridge is a cheap price range restaurant with a customer rating of 5 out of 5.
# for a restaurant  with customer Rating 5 out of 5, the Taste of Cambridge offers meals in the more than £30 price Range
# The Taste of Cambridge is an over- expensive restaurant that isn't very good.
# The Taste of Cambridge, a moderately priced restaurant, is a great place to eat if you are looking for a regular meal.
# Taste of Cambridge  is a high priced restaurant that has a customer rating of 1 of of 5.
# Taste of Cambridge has low customer ratings and is a low-priced restaurant.
# Taste of Cambridge is a restaurant with average ratings from customers. Price range is about less than £20.
# If you want cheap in price, but not in taste come by The Taste of Cambridge.   Try the restaurant that received a customer rating of 5 out of 5.
# The restaurant,Taste of Cambridge has a moderate price range with a 3 out of 5 star customer rating.
# Taste of Cambridge is a moderately priced restaurant with a 1 out of 5 rating
# In the high price range, the Taste of Cambridge restaurant is rated by customers at 3 out of 5.
# Taste of Cambridge, is restaurant  located average less than £20
# Taste of Cambridge is an average restaurant offering meals for less than £20.
# The Taste of Cambridge restaurant has a price range of more than 30. Its customer rating is 5 out of 5.
# A cheap restaurant called Taste of Cambridge has an excellence customer rating of 5 out of 5.
# Taste of Cambridge is a high priced restaurant with an average customer rating.
# Taste of Cambridge is a high customer rated restaurant with a price range of more than £30.
# Taste of Cambridge gets 1 out of 5 stars and is a moderately priced restaurant.
# Taste of Cambridge has a low rating. its prices are more than £30.
# Despite its low rating, The Taste of Cambridge restaurant features meals for less than £20.
# Taste of Cambridge restaurant for average customer Rating  in high price Range
# Taste of Cambridge is a highly rated restaurant with average price range of £20-25.
# Taste of Cambridge is a moderately priced restaurant with a customer rating of 1 out of 5.
# Taste of Cambridge restaurant for average customer Rating  in high price Range
# Taste of Cambridge is a restaurant where the price range is more than £30. It has a low customer rating.
# Taste of Cambridge is a high customer rating restaurant with a price range of £20-25.
# Taste of Cambridge restaurant has a high price range but a low customer rating.
# Taste of Cambridge is a high end restaurant providing meals in the £20-25 range.
# restaurant Taste of Cambridge has a price range of £20-25 and is customer rated 3 out of 5.
# Taste of Cambridge, a restaurant, has a 3 out of 5 customer rating with a price range of 20-25 pounds.
# Taste of Cambridge is an expensive restaurant. It has a high customer rating.
# Taste of Cambridge is a restaurant with a high price range.  Customers rate this restaurant as 5 out of 5.
# It has a customer rating of 5 out of 5. Taste of Cambridge is a cheap restaurant.
# 1 out of 5 customer rating restaurant with a moderate price range  is Taste of Cambridge
# There is a cheap restaurant called Taste of Cambridge with an average rating by its customers.
# A highly rated restaurant called Taste of Cambridge with a reasonable price tag.
# Taste of Cambridge restaurant offers meals for less than £20 and has an average rating.
# Taste of Cambridge has an average customer rating with a price range less than 20 is a eat type restaurant.
# High price range restaurant called Taste of Cambridge has an average customer rating.
# the price is high to eat at a restaurant with an average customer rating called Taste of Cambridge.
# £20-25 dishes. The Taste of Cambridge restaurant.  Customer Rating: 3 of 5.
# Taste of Cambridge is a highly rated restaurant with a moderate price range
# The moderately priced restaurant, Taste of Cambridge, has a 3 out of 5 star customer rating.
# Taste of Cambridge has a high customer rating, but is expensive.
# The Taste of Cambridge is a regular rated location with moderately priced food.
# Taste of Cambridge is a cheap restaurant with a 5 out of 5 customer rating.
# The Taste of Cambridge restaurant has a low customer rating of 1 out of 5 due to a high price range.
# Taste of Cambridge is a  restaurant  in the high price range. Its customer rating is high.
# Taste of Cambridge is a high-priced restaurant with customer rating 3 out of 5.
# A highly rated restaurant, the Taste of Cambridge offers fine dining for £20 - 25.
# Taste of Cambridge is a low-price restaurant, but has low customer ratings.
# Taste of Cambridge is a cheap restaurant that is given an average rating by its customers.
# a restaurant that is less than £20 and has a low customer rating is Taste of Cambridge
# Taste of Cambridge is a highly rated, average priced restaurant.
# The Taste of Cambridge restaurant has a price range of £20-25 and has a 3 out of 5 customer rating.
# Taste of Cambridge is a restaurant  with high priced and customer rating of 1 of of 5.
# If you are looking for a restaurant with high ratings and a price range of £20-25, try the Taste of Cambridge.
# Taste of Cambridge restaurant has a high price range and customer rating of 3 out of 5.
# The restaurant Taste of Cambridge has a customer rating of 3 out of 5 and a moderate price range.
# The Taste of Cambridge is a restaurant with a  price range of less than £20. The customer ratings are average.
# Taste of Cambridge is a high priced restaurant. Its customer rating is 3 out of 5.
# Taste of Cambridge is a cheap restaurant with an average customer rating.
# The Taste of Cambridge restaurant is a cheap place to eat with an average customer rating.
# Taste of Cambridge is  a restaurant that is less than £20 and has a low customer rating
# Taste of Cambridge is a restaurant with high customer ratings.  The price range at this restaurant is slightly higher than average.  Prices are above £30.
# Taste of Cambridge is a restaurant which is rated highly by customers. The price range is over £30
# An average restaurant at the less than £20 price range is the Taste of Cambridge.
# The Taste of Cambridge is a high priced restaurant and has a customer rating of 3 out of 5.
# The Taste of Cambridge restaurant has a 3 out of 5 rating and has a high price.
# An expensive restaurant with a high customer Rating is Taste of Cambridge.
# Taste of Cambridge restaurant has a high price range but only a 1 out of 5 customer rating.
# A low rated restaurant in the price range of less than £20 is Taste of Cambridge.
# Taste of Cambridge is a restaurant with a moderate price range and a customer rating of 3 out of 5.
# restaurant called Taste of Cambridge has a low customer rating and moderate prices.
# A high price restaurant called Taste of Cambridge got a good customer rating
# The Taste of Cambridge restaurant is average and the price is less than £20.

# %%
def get_attributes(df: pd.DataFrame):
	attributes = set()
	area_count = 0
	food_count = 0
	near_count = 0
	price_range_count = 0
	customer_rating = 0
	family_friendly_count = 0
	eat_type_count = 0
	name_count = 0
	for i, row in df.iterrows():
		text = row["mr"]
		
		for element in text.split(","):
			attribute = element.split("[")[0].strip()
			if attribute == "food":
				food_count += 1
			elif attribute == "near":
				near_count += 1
			elif attribute == "priceRange":
				price_range_count += 1
			elif attribute == "area":
				area_count += 1
			elif attribute == "customer rating":
				customer_rating += 1
			elif attribute == "familyFriendly":
				family_friendly_count += 1
			elif attribute == "eatType":
				eat_type_count += 1
			elif attribute == "name":
				name_count += 1
			attributes.add(attribute)

	print(f"Did not find area attribute in {len(df) - area_count} rows")
	print(f"Did not find food attribute in {len(df) - food_count} rows")
	print(f"Did not find near attribute in {len(df) - near_count} rows")
	print(f"Did not find price_range attribute in {len(df) - price_range_count} rows")
	print(f"Did not find customer_rating attribute in {len(df) - customer_rating} rows")
	print(f"Did not find family_friendly attribute in {len(df) - family_friendly_count} rows")
	print(f"Did not find eat_type attribute in {len(df) - eat_type_count} rows")
	print(f"Did not find name attribute in {len(df) - name_count} rows")

	return attributes

# %%
print(len(data_df))
# Out:
# 33525

# %%
get_attributes(data_df)
# Out:
# Did not find area attribute in 13520 rows
# Did not find food attribute in 4551 rows
# Did not find near attribute in 19240 rows
# Did not find price_range attribute in 10004 rows
# Did not find customer_rating attribute in 10253 rows
# Did not find family_friendly attribute in 12762 rows
# Did not find eat_type attribute in 17645 rows
# Did not find name attribute in 0 rows
# {'area',
#  'customer rating',
#  'eatType',
#  'familyFriendly',
#  'food',
#  'name',
#  'near',
#  'priceRange'}

# %%
def get_unique_attribute_values(df: pd.DataFrame, attr: str):
	attrs = set()
	for _, row in df.iterrows():
		pattern = rf"{attr}\[(?P<attr_type>[^\]]+)\]"
		pattern_match = re.search(pattern, row["orig_mr"])
		if pattern_match:
			attr_type = pattern_match.group("attr_type").strip()
			attrs.add(attr_type)

	return attrs

# %%
name_attrs = get_unique_attribute_values(data_df, "name")

with open("data/unique_names.txt", "w") as f:
	f.write("\n".join(name_attrs))

# %%
data_df.to_csv("data/train.csv")
